# %%
from hyperspace.kepler.data_utils import load_results
from hyperspace.kepler.plots import plot_convergence

from skopt.plots import plot_objective 
import matplotlib.pyplot as plt
from matplotlib.pyplot import savefig

import matplotlib
matplotlib.rcParams['figure.figsize']=[12, 12]
# %matplotlib inline

# %%
def objective(space):
    # New setting for each hyperparameter;
    dense_neurons,feature_maps,latent_dim,conv_layers,filter_shapes = space;
    # parameters for model;
    channels = 1;
    feature_maps = [feature_maps]*conv_layers;
    filter_shapes = [(filter_shapes,filter_shapes)]*conv_layers;
    dense_layers = 1;
    dense_neurons = [dense_neurons];
    strides = [(1,1),(2,2),(1,1),(1,1)];
    strides = strides[0:conv_layers];
    dense_dropouts = [0];
    epochs = 15;
    batch_size = 100;
    #print("parameters selected:");
    #print(image_size,channels,conv_layers,feature_maps,filter_shapes,strides,dense_layers,dense_neurons,
    #    dense_dropouts,latent_dim);
    # build model;
    autoencoder = conv_variational_autoencoder(image_size,channels,conv_layers,feature_maps, filter_shapes,strides,
        dense_layers,dense_neurons,dense_dropouts,latent_dim);
        # train;
    autoencoder.train(X_train[0:],batch_size,epochs=epochs,
                            validation_data=(X_test[0:],X_test[0:]),
                            checkpoint=False);
    # loss function;
    avg_loss = np.mean(autoencoder.history.val_losses[-10:]);
    return avg_loss;

# %%
import os
import re

import pickle
from skopt import load

def _listfiles(results_path):
    """
    Creates a list of result files names.
    Parameters:
    ----------
    * `results_path`: [str]
        Path to the saved results.
    """
    files = []
    for file in os.listdir(results_path):
        # Sort files by MPI rank: used for checkpointing.
        files.append(file)
    
    files = sorted(files)
    return files 


def load_results(results_path, sort=False, reverse_sort=False):
    """
    Loads results from distributed run with Scikit-Optimize.
    Parameters
    ----------
    * `results_path` [string]
        Path where results from the distributed run is stored.
    * `sort` [Bool, default=False]
        Sorts results by objective function minimum (lowest first).
    * `reverse_sort` [Bool, defaul=False]
        Sort results by objective function minimum (highest first.)
        - `sort` must be set to True.
    Returns
    -------
    * results [list]
    """
    files = _listfiles(results_path) 

    ranks = []
    results = []
    for file in files:
        #rank = re.findall(r'\d+', file)
        #rank = int(rank[0])
        #ranks.append(rank)
        full_path = os.path.join(results_path, file)
        results.append(load(str(full_path)))

    if reverse_sort and not sort:
        sort = True

    if sort:
        results = sorted(results, key=lambda result: result.fun)

    return results

# %%
fs_peptide = load_results(results_path='../optim_results/fspeptide/')
twof4k = load_results(results_path='../optim_results/2f4k/')
onefme = load_results(results_path='../optim_results/1fme/')

fs_peptide = fs_peptide[0]
twof4k = twof4k[0]
onefme = onefme[0]

# %%
# print(onefme.x_iters[8])
# print(onefme.x_iters)

# %%
#print(onefme.func_vals)

# %%
onefme.fun
# Out:
# 24.308955520982188

# %%
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']});
rc('text', usetex=True);

from scipy.interpolate import interp1d

onefme_dim = []
onefme_loss = []
for i in onefme.func_vals:
    onefme_loss.append(i)

for i in onefme.x_iters:
    #print(twof4k.x_iters)
    onefme_dim.append(i[2])

from matplotlib import rcParams
rcParams.update({'figure.autolayout': True});

fig = plt.figure(figsize=(6,4));
ax = fig.add_subplot(111, facecolor='white');
ax.spines["top"].set_visible(False); 
ax.spines["bottom"].set_visible(True);
ax.spines["bottom"].set_color('gray');
ax.spines["right"].set_visible(False);    
ax.spines["left"].set_visible(True);
ax.spines["left"].set_color('gray');
ax.minorticks_off;
ax.patch.set_facecolor('white');

ax.get_xaxis().tick_bottom();  
ax.get_yaxis().tick_left();
ax.set_ylim([0, 80]);
line1, = ax.plot(onefme_dim, onefme_loss, 'o')

ax.tick_params(axis='both', which='major', labelsize=20);
ax.set_ylabel('Loss ($\mathcal{L}$)', fontsize=20)
ax.set_xlabel('Latent Dimension', fontsize=20)
ax.legend(loc='upper right')
savefig('1fme_loss_latent.png', bbox_inches='tight', dpi=600)
plt.show()
# Out:
# /Users/youngtodd/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /Users/youngtodd/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
matplotlib.rcParams['figure.figsize']=[10, 10]
from matplotlib import rc

rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']});
rc('text', usetex=True);

from scipy.interpolate import interp1d

onefme_dim = []
onefme_loss = []
for i in onefme.func_vals:
    onefme_loss.append(i)

for i in onefme.x_iters:
    #print(twof4k.x_iters)
    onefme_dim.append(i[2])

fig = plt.figure(figsize=(6,4));
fig, ax = plt.subplots()
ax = plt.subplot( axisbg='white'); 
ax.spines["top"].set_visible(False); 
ax.spines["bottom"].set_visible(True);
ax.spines["bottom"].set_color('gray');
ax.spines["right"].set_visible(False);    
ax.spines["left"].set_visible(True);
ax.spines["left"].set_color('gray');

ax.get_xaxis().tick_bottom();  
ax.get_yaxis().tick_left();
ax.set_ylim([0, 80]);
line1, = ax.plot(onefme_dim, onefme_loss, 'o')

ax.set_ylabel('Loss ($\mathcal{L}$)')
ax.set_xlabel('Latent Dimension')
ax.legend(loc='upper right')
#savefig('1fme_loss_latent.png', bbox_inches='tight')
plt.show()
# Out:
# /Users/youngtodd/anaconda3/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /Users/youngtodd/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /Users/youngtodd/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
import numpy as np
np.std(onefme_loss)
# Out:
# 13.480937761933495

# %%
print(fs_peptide.x)
print(fs_peptide.fun)
print(fs_peptide.x_iters)
print(fs_peptide.func_vals[8])
# Out:
# [64, 100, 10, 4, 5]
# 7.823165426789119
# [[51, 87, 9, 4, 4], [44, 41, 2, 2, 3], [58, 56, 5, 4, 3], [53, 47, 10, 1, 5], [47, 83, 6, 3, 4], [51, 61, 8, 1, 3], [38, 78, 4, 1, 3], [37, 35, 5, 4, 3], [52, 92, 3, 4, 4], [37, 46, 8, 3, 3], [55, 64, 9, 1, 4], [51, 89, 9, 4, 4], [51, 100, 9, 4, 4], [55, 100, 9, 4, 4], [46, 100, 9, 4, 4], [45, 100, 10, 4, 4], [32, 100, 10, 4, 3], [48, 100, 10, 4, 4], [56, 100, 10, 4, 5], [64, 100, 10, 4, 5]]
# 23.241774801697055

# %%
import numpy as np

fspeptide_dim = []
fspeptide_loss = []
for i in fs_peptide.func_vals:
    fspeptide_loss.append(i)

for i in fs_peptide.x_iters:
    #print(twof4k.x_iters)
    fspeptide_dim.append(i[2])
    
np.std(fspeptide_loss)
# Out:
# 8.674614320107445

# %%
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True});

fig = plt.figure(figsize=(6,4));
ax = fig.add_subplot(111, facecolor='white');
ax.spines["top"].set_visible(False); 
ax.spines["bottom"].set_visible(True);
ax.spines["bottom"].set_color('gray');
ax.spines["right"].set_visible(False);    
ax.spines["left"].set_visible(True);
ax.spines["left"].set_color('gray');
ax.minorticks_off;
ax.patch.set_facecolor('white');

line1, = ax.plot(fspeptide_dim, fspeptide_loss, 'o')

ax.tick_params(axis='both', which='major', labelsize=20);
ax.set_ylabel('Loss ($\mathcal{L}$)', fontsize=20)
ax.set_xlabel('Latent Dimension', fontsize=20)
ax.legend(loc='upper right')
savefig('fspeptide_loss_latent.png', bbox_inches='tight', dpi=600)
plt.show()
# Out:
# /Users/youngtodd/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /Users/youngtodd/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
print(twof4k.fun)
print(twof4k.x)
print(twof4k.func_vals)
print(twof4k.x_iters)
# Out:
# 74.66472861262302
# [58, 99, 9, 4, 5]
# [7.64575436e+01 1.33595143e+02 1.02260857e+02 8.12833259e+01
#  9.25274586e+01 9.47331621e+01 1.17526531e+02 1.05867797e+02
#  1.13072129e+02 8.94134486e+01 7.46647286e+01 9.10033559e+01
#  6.07834076e+27 9.75879170e+01 1.05678513e+02 8.87306011e+01
#  8.92717350e+01 1.34421829e+02 1.00289798e+02 9.32134726e+01]
# [[51, 87, 9, 4, 4], [44, 41, 2, 2, 3], [58, 56, 5, 4, 3], [53, 47, 10, 1, 5], [47, 83, 6, 3, 4], [51, 61, 8, 1, 3], [38, 78, 4, 1, 3], [37, 35, 5, 4, 3], [52, 92, 3, 4, 4], [37, 46, 8, 3, 3], [58, 99, 9, 4, 5], [32, 100, 10, 4, 5], [59, 89, 9, 4, 5], [48, 55, 5, 4, 5], [45, 74, 5, 2, 3], [52, 34, 9, 1, 4], [48, 64, 7, 3, 4], [51, 72, 2, 2, 2], [54, 50, 6, 1, 5], [53, 87, 6, 3, 4]]

# %%
twof4k_dim = []
twof4k_loss = []
for i in twof4k.func_vals:
    twof4k_loss.append(i)

for i in twof4k.x_iters:
    #print(twof4k.x_iters)
    twof4k_dim.append(i[2])
    
np.std(twof4k_loss)
# Out:
# 1.3247436553130857e+27

# %%
print(twof4k_dim)
print(twof4k_loss)
# Out:
# [9, 2, 5, 10, 6, 8, 4, 5, 3, 8, 9, 10, 9, 5, 5, 9, 7, 2, 6, 6]
# [76.45754356016006, 133.5951434317657, 102.26085655676467, 81.28332590026515, 92.52745856331929, 94.73316205991166, 117.52653054799353, 105.8677968450955, 113.07212911222662, 89.41344857045581, 74.66472861262302, 91.00335594092097, 6.078340757480442e+27, 97.58791698826211, 105.67851282622132, 88.73060113868544, 89.27173499545881, 134.42182939972196, 100.28979786949496, 93.21347258708307]

# %%
del twof4k_loss[12]
del twof4k_dim[12]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(6,4));
ax = fig.add_subplot(111, facecolor='white');
ax.spines["top"].set_visible(False); 
ax.spines["bottom"].set_visible(True);
ax.spines["bottom"].set_color('gray');
ax.spines["right"].set_visible(False);    
ax.spines["left"].set_visible(True);
ax.spines["left"].set_color('gray');
ax.minorticks_off;
ax.patch.set_facecolor('white');

ax.get_xaxis().tick_bottom();  
ax.get_yaxis().tick_left();
ax.set_ylim([60, 140]);


line1, = ax.plot(twof4k_dim, twof4k_loss, 'o')

ax.tick_params(axis='both', which='major', labelsize=20);
ax.set_ylabel('Loss ($\mathcal{L}$)', fontsize=20)
ax.set_xlabel('Latent Dimension', fontsize=20)
ax.legend(loc='upper right')
savefig('2f4k_loss_latent.png', bbox_inches='tight', dpi=600)
plt.show()
# Out:
# /Users/youngtodd/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /Users/youngtodd/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
import numpy as np

np.std(loss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-af830bb6109e> in <module>()
#       1 import numpy as np
#       2
# ----> 3 np.std(loss)
#
# NameError: name 'loss' is not defined

# %%
print('fs-peptide average loss with optimal parameters: {}\n'.format(fs_peptide.fun))
print('2f4k average loss with optimal parameters: {}\n'.format(twof4k.fun))
print('1fme average loss with optimal parameters: {}\n'.format(onefme.fun))
# Out:
# fs-peptide average loss with optimal parameters: 7.823165426789119
#
# 2f4k average loss with optimal parameters: 74.66472861262302
#
# 1fme average loss with optimal parameters: 24.308955520982188

# %% [markdown]
# dense_neurons,feature_maps,latent_dim,conv_layers,filter_shapes

# %%
params = ['n_dense_neurons', 'n_conv_filters', 'latent_dim', 'n_conv_layers', 'filter_shape']
plot_objective(fs_peptide, dimensions=params)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x108d49940>,
# ...
#       dtype=object)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     330                 pass
#     331             else:
# --> 332                 return printer(obj)
#     333             # Finally look for special method names
#     334             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     235
#     236     if 'png' in formats:
# --> 237         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     238     if 'retina' in formats or 'png2x' in formats:
#     239         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %%
plot_objective(onefme, dimensions=params)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x109bebb38>,
# ...
#       dtype=object)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     330                 pass
#     331             else:
# --> 332                 return printer(obj)
#     333             # Finally look for special method names
#     334             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     235
#     236     if 'png' in formats:
# --> 237         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     238     if 'retina' in formats or 'png2x' in formats:
#     239         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %%
plot_objective(twof4k, dimensions=params)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a25a62780>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a261e1e10>]], dtype=object)

# %%
matplotlib.rcParams['figure.figsize']=[14, 14]
plot_convergence(fs_peptide, onefme, twof4k)

# %%
plot_convergence(fs_peptide)

# %%
plot_convergence(onefme)

# %%
plot_convergence(twof4k)
